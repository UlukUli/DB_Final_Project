# %%
from sqlalchemy import create_engine
import pandas as pd

MYSQL_USER = "root"
MYSQL_PASSWORD = "usql12liutop_81"
MYSQL_HOST = "localhost"
MYSQL_PORT = 3306
MYSQL_DB = "hotel_db"

connection_url = (
    f"mysql+mysqlconnector://{MYSQL_USER}:{MYSQL_PASSWORD}"
    f"@{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DB}"
)

engine = create_engine(connection_url)
engine

# %%
import pandas as pd

df = pd.read_csv("../data/hotel_bookings.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/hotel_bookings.csv")
#       4 df.head()
#
# File C:\DB_Final_Project\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/hotel_bookings.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/hotel_bookings.csv")
#       4 df.head()
#
# File C:\DB_Final_Project\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os

print("We are in:", os.getcwd())
print("Root files:", os.listdir())
# Out:
# We are in: C:\DB_Final_Project\notebooks
# Root files: ['.ipynb_checkpoints', 'ai_agent.ipynb']

# %%
import pandas as pd

df = pd.read_csv("../data/hotel_bookings.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/hotel_bookings.csv")
#       4 df.head()
#
# File C:\DB_Final_Project\venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_excel("../data/hotel_bookings.xlsx")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel("../data/hotel_bookings.xlsx")
#       4 df.head()
#
# File C:\DB_Final_Project\venv\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
import pandas as pd

df = pd.read_excel("../data/hotel_bookings.xlsx")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel("../data/hotel_bookings.xlsx")
#       4 df.head()
#
# File C:\DB_Final_Project\venv\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/hotel_bookings.xlsx", encoding='utf-8', sep=',', engine='python')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/hotel_bookings.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# ⚠️ ВАЖНО: сюда впиши свой пароль от MySQL
MYSQL_USER = "root"
MYSQL_PASSWORD = "usql12liutop_81"   # поменяй тут
MYSQL_HOST = "localhost"
MYSQL_PORT = 3306
MYSQL_DB = "hotel_db"

connection_url = (
    f"mysql+mysqlconnector://{MYSQL_USER}:{MYSQL_PASSWORD}"
    f"@{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DB}"
)

engine = create_engine(connection_url)
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost:3306/hotel_db)

# %%
import pandas as pd
from sqlalchemy import create_engine

MYSQL_USER = "root"
MYSQL_PASSWORD = "usql12liutop_81"
MYSQL_HOST = "localhost"
MYSQL_PORT = 3306
MYSQL_DB = "hotel_db"

connection_url = (
    f"mysql+mysqlconnector://{MYSQL_USER}:{MYSQL_PASSWORD}"
    f"@{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DB}"
)

engine = create_engine(connection_url)
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost:3306/hotel_db)

# %%
from sqlalchemy import create_engine
import pandas as pd

MYSQL_USER = "root"
MYSQL_PASSWORD = "usql12liutop_81"  # сюда тот же пароль, что ты вводишь в MySQL Workbench
MYSQL_HOST = "localhost"
MYSQL_PORT = 3306
MYSQL_DB = "hotel_db"

connection_url = (
    f"mysql+mysqlconnector://{MYSQL_USER}:{MYSQL_PASSWORD}"
    f"@{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DB}"
)

engine = create_engine(connection_url)
engine

# %%
import pandas as pd

pd.read_sql("SHOW TABLES;", engine)

# %% [markdown]
# # AI Agent for Hotel Booking Database
#
# ## Project Overview
# This notebook implements an AI-powered assistant for working with a hotel bookings relational database.
# The agent should:
# - Understand natural language questions.
# - Generate SQL queries to the database.
# - Return analytical results and insights.
#
# ## Business Problems
#
# 1. Booking Cancellations
#
# Goal: Identify which types of customers are more likely to cancel their bookings and what factors contribute to higher cancellation rates.
#
# 2. Hotel Occupancy by Month
#
# Goal: Determine which months have higher booking volumes and compare occupancy trends between the City Hotel and the Resort Hotel.
#
# 3. Popular Room Types
#
# Goal: Analyze which room types are booked most frequently and how this varies by customer type and season.
#
# 4. Revenue by Market Segment
#
# Goal: Evaluate which market segments (e.g., Corporate, Direct, Online) generate the highest revenue for the hotel.
#
# 5. Impact of Meal Plans on Bookings
#
# Goal: Understand which meal plans (BB, HB, FB, SC) are in highest demand and how meal preferences relate to customer types and booking behavior.
#
# ## Team Roles
# - Architect – database structure and ERD
# - Analyst – business problems, metrics, EDA
# - SQL Developer – tables, indexes, views
# - AI Engineer – AI agent, text-to-SQL, analytics in Python

# %%
df.info()

# %%
df.isna().sum()

# %%
df.nunique()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-v0_8")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
import pandas as pd
df = pd.read_csv("../data/hotel_bookings.csv")

# %%
import sys
sys.executable

# %%
import sys
import subprocess

subprocess.check_call([sys.executable, "-m", "pip", "install", "matplotlib", "seaborn"])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborn-v0_8")

# %%
import sys
sys.executable

# %%
import matplotlib
import seaborn
print("OK")

# %%
df.info()
df.isnull().sum()

# %%
import pandas as pd
df = pd.read_csv("../data/hotel_bookings.csv")

# %%
df.info()
df.isnull().sum()

# %%
df.info()
df.isnull().sum()
df.describe()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,4))
sns.countplot(data=df, x="is_canceled")
plt.title("Booking Cancellations (0 = not canceled, 1 = canceled)")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(
    data=df,
    x="arrival_date_month",
    order=["January","February","March","April","May","June",
           "July","August","September","October","November","December"]
)
plt.xticks(rotation=45)
plt.title("Bookings by Month")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.countplot(data=df, x="reserved_room_type")
plt.title("Most Popular Reserved Room Types")
plt.show()

# %%
SCHEMA_DESCRIPTION = """
TABLE: hotel_bookings (one row per hotel booking)

Columns:
- hotel: type of hotel (Resort Hotel, City Hotel)
- is_canceled: booking canceled (1) or not (0)
- lead_time: days between booking and arrival
- arrival_date_year: year of arrival
- arrival_date_month: month of arrival (text)
- arrival_date_week_number: ISO week number
- arrival_date_day_of_month: day of month (1–31)
- stays_in_weekend_nights: number of weekend nights stayed
- stays_in_week_nights: number of week nights stayed
- adults: number of adults
- children: number of children
- babies: number of babies
- meal: meal type (BB, HB, FB, SC)
- country: country of origin
- market_segment: booking channel (Online TA, Offline TA, Corporate, Direct...)
- distribution_channel: distribution type (TA/TO, Direct, Corporate, GDS...)
- is_repeated_guest: 1 if guest stayed before, else 0
- previous_cancellations: number of past cancellations by this customer
- reserved_room_type: reserved room code (A,B,C...)
- assigned_room_type: assigned room code
- booking_changes: number of changes to booking
- deposit_type: No Deposit / Non Refund / Refundable
- agent: agent id
- company: company id
- days_in_waiting_list: how long booking waited
- customer_type: Transient, Contract, Group...
- adr: Average Daily Rate (price per night per occupied room)
- required_car_parking_spaces: parking spaces
- total_of_special_requests: count of special requests
"""

# %%
reference_queries = {
    "cancellation_rate_by_hotel": """
        SELECT
            hotel,
            AVG(is_canceled) AS cancellation_rate
        FROM hotel_bookings
        GROUP BY hotel;
    """,

    "bookings_by_month": """
        SELECT
            arrival_date_month,
            COUNT(*) AS total_bookings
        FROM hotel_bookings
        GROUP BY arrival_date_month
        ORDER BY total_bookings DESC;
    """,

    "popular_room_types": """
        SELECT
            reserved_room_type,
            COUNT(*) AS total_bookings
        FROM hotel_bookings
        GROUP BY reserved_room_type
        ORDER BY total_bookings DESC;
    """,

    "revenue_by_market_segment": """
        SELECT
            market_segment,
            SUM(adr * (stays_in_weekend_nights + stays_in_week_nights)) AS total_revenue
        FROM hotel_bookings
        WHERE is_canceled = 0
        GROUP BY market_segment
        ORDER BY total_revenue DESC;
    """,

    "adr_by_month_and_hotel": """
        SELECT
            hotel,
            arrival_date_month,
            AVG(adr) AS avg_adr
        FROM hotel_bookings
        WHERE is_canceled = 0
        GROUP BY hotel, arrival_date_month
        ORDER BY hotel, arrival_date_month;
    """
}

# %%
def build_sql_prompt(user_question: str) -> str:
    return f"""
You are an expert MySQL analyst for a hotel bookings database.

Database schema:
{SCHEMA_DESCRIPTION}

Task:
- Given the user question, write ONE valid MySQL SELECT query.
- Use only existing columns.
- Do NOT explain the query, output ONLY raw SQL.

User question: "{user_question}"

SQL:
""".strip()

# %%
def fake_generate_sql(user_question: str) -> str:
    q = user_question.lower()

    if "cancel" in q:
        return reference_queries["cancellation_rate_by_hotel"]
    if "month" in q:
        return reference_queries["bookings_by_month"]
    if "room" in q:
        return reference_queries["popular_room_types"]
    if "segment" in q or "market" in q:
        return reference_queries["revenue_by_market_segment"]
    if "adr" in q or "price" in q:
        return reference_queries["adr_by_month_and_hotel"]

    # fallback — временно
    return "SELECT 1;"

# %%
question = "What is the cancellation rate by hotel type?"
print(fake_generate_sql(question))

# %%
import sys
sys.executable
